# %% [markdown]
# Input

# %%
from x import Post_Constructor as pc
pc = pc()
pc.get_news(pc.news_importer.google_search('site:finviz.com TSLA after:2025-12-30', engine='google_news'))

# %% [markdown]
# Print Headlines/Results

# %%
pc.news_results
# Out:
# [(0,
#   ('Big Moves On The Horizon For Tesla Stock With These Two Deadlines Looming',
#    'https://www.investors.com/news/tesla-stock-big-moves-on-the-horizon-with-these-two-deadlines-looming/')),
#  (1,
#   ('Tesla’s (TSLA) Cybercab is Already Making an Impact in Austin',
#    'https://www.tipranks.com/news/teslas-tsla-cybercab-is-already-making-an-impact-in-austin')),
#  (2,
#   ('Tesla previews its Q4 deliveries',
#    'https://finance.yahoo.com/video/tesla-previews-q4-deliveries-215249656.html')),
#  (3,
#   ('‘We Want to Own It,’ Says Top Analyst About Tesla Stock (TSLA)',
#    'https://www.tipranks.com/news/we-want-to-own-it-says-top-analyst-about-tesla-stock-tsla')),
#  (4,
#   ('Tesla Broadcasts Downbeat Car Sales Estimates in Unusual Move',
#    'https://www.bloomberg.com/news/articles/2025-12-30/tesla-tsla-compiles-downbeat-average-estimates-for-its-vehicle-sales')),
#  (5,
#   ('TSLA Stock Watch! Investor Michael Burry Rules Out Tesla Short Position',
# ...

# %%
Construct Post and Send to X

# %%
post=pc.construct_post(headline=pc.news_results[0][1][0], link=pc.news_results[0][1][1], symbol='TSLA')
