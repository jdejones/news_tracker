# %% [markdown]
# Run and Instantiate

# %%
# %run user_interface.py
ui = UserInterface()
ui.scrape_news()
ui.process_headlines()
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\jdejo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# Observe bigrams/trigrams

# %%
ui.ngrams_frame()[:50]
# Out:
#         mono                         bi        \
#       ngrams      n              ngrams     n
# 0      stock  107.0            (p, 500)  20.0
# 1          ’   78.0     (stock, market)  19.0
# 2      trump   69.0      (wall, street)  16.0
# 3     market   58.0       (stock, make)  15.0
# 4        say   55.0     (make, biggest)  13.0
# 5       2026   50.0     (biggest, move)  13.0
# 6       2025   47.0      (market, open)  13.0
# 7        new   42.0      (record, high)  12.0
# 8         ai   39.0          (5, thing)  12.0
# 9       year   37.0       (thing, know)  12.0
# 10    record   27.0       (know, stock)  12.0
# 11      make   26.0      (market, news)  12.0
# 12      rate   26.0        (news, dec.)  12.0
# 13      move   26.0     (novo, nordisk)   8.0
# 14       top   25.0       (oil, tanker)   8.0
# 15      u.s.   24.0      (data, center)   8.0
# 16  christma   24.0   (move, premarket)   8.0
# 17       fed   24.0     (epstein, file)   8.0
# ...

# %% [markdown]
# Find headlines containing topic of interest

# %%
ui.find_headline('gold')
# Out:
# [(0, 'Gold climbs above $4,500 in historic rally for metals'),
#  (1, 'Gold tops $4500 while silver, platinum surge to new peaks'),
#  (2,
#   "Gold, Silver, and Copper Are All Hitting Record Highs—Here's What's Driving the Frenzy"),
#  (3,
#   "China Gold Shock: Beijing Smashes Records To Build A New 'De-Dollarised' Economy"),
#  (4,
#   'Markets News, Dec. 18, 2025: Stock Indexes Close Sharply Higher After Cool Inflation Data; Dow, S&P 500 Snap 4-Session Skids; Gold Hits New Record'),
#  (5, 'Gold climbs above $4,500 in historic rally for precious metals'),
#  (6,
#   'Markets News, Dec. 22, 2025: Stock Indexes End Higher for 3rd Straight Session as Tech Shares Continue Advance; Gold, Silver Hit Fresh Record Highs'),
#  (7,
#   "U.S.-China soybean tussle reveals food security goals. Goldman's stock plays"),
#  (8,
#   'Goldman says these energy stocks are outperforming but underappreciated'),
#  (9, 'S&P 500, Dow hit all-time closing highs; gold, silver touch records'),
#  (10,
# ...

# %% [markdown]
# Example of selecting a headline

# %%
ui.find_headline('gold')[3][1]
# Out:
# "China Gold Shock: Beijing Smashes Records To Build A New 'De-Dollarised' Economy"

# %% [markdown]
# Store 1 headline

# %%
ui.store_headlines(topic='gold', headlines=[ui.find_headline('gold')[3][1]])
# Out:
# 1

# %% [markdown]
# Store multiple headlines

# %%
ui.store_headlines(topic='gold', headlines=[item[1] for item in ui.find_headline('gold')])
# Out:
# 15
